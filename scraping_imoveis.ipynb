# %% [markdown]
# Importando bibliotecas

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import math
from time import sleep

# %% [markdown]
# Obtendo dados da página

# %%
pagina = 1

# %%
prefix = "https://www.imovelweb.com.br"

# %%
webpage_response = requests.get(("https://www.imovelweb.com.br/comerciais-aluguel-sao-paulo-sp-pagina-{}.html").format(pagina))

# %%
webpage = webpage_response.content

# %%
soup = BeautifulSoup(webpage, "html.parser")

# %%
total = math.ceil(int(soup.find("h1", {"class":"list-result-title"}).b.text.replace(".", ""))/20)

# %%
realty_links = []

# %%
for p in range(total):
    try:
        webpage_response = requests.get(("https://www.imovelweb.com.br/comerciais-aluguel-sao-paulo-sp-pagina-{}.html").format(pagina), verify = False)
        webpage = webpage_response.content
        soup = BeautifulSoup(webpage, "html.parser")
        realty_links.extend(soup.find_all("a", {"class": "go-to-posting"}))
        pagina += 1
        sleep(10)
    except:
        pass
# Out:
# C:\Users\deiam\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.imovelweb.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# C:\Users\deiam\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.imovelweb.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# C:\Users\deiam\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.imovelweb.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ...

# %%
len(realty_links)
# Out:
# 13420

# %% [markdown]
# Incluindo links para imóveis em uma lista

# %%
links = []

# %%
for a in realty_links:
    links.append(prefix+a["href"])

# %%
len(links)
# Out:
# 13420

# %%
sites = pd.DataFrame(links)

# %%
sites.to_csv('sites_aluguel1.csv', index=False, encoding='cp1252')

# %%
df = pd.read_csv('sites_aluguel.csv')
links = df.iloc[1:10000,0]

# %%
realty_data2 = []
for link in links:
    webpage = requests.get(link, verify = False)
    realty = BeautifulSoup(webpage.content, "html.parser")
    data = {}
    for i in realty.find_all("span", {"class":"publisher-code"}):
        try:
            n_code = i.b.text
            i.b.extract()
            code = i.get_text(strip=True)
            data[n_code] = code
        except AttributeError:
            data[code] = 0
        except AttributeError:
            data[expense] = 0
    for li in realty.find_all("li", {"class":"icon-feature"}):
        try:
            tam = li.b.text.strip("m²")
            f_type = li.span.text
            data[f_type] = tam
        except AttributeError:
            data[f_type] = ""
        except AttributeError:
            data[f_type] = ""
    l = realty.find('h2',{'class': 'title-location'})
    try:
        neighborhood = l.span.text.split(",")
        l.span.extract()
        address = l.get_text(strip=True)
        data['endereço'] = address
        data['bairro'] = neighborhood[1]
        data['cidade'] = neighborhood[2]
    except AttributeError:
        data['endereço'] = ""
        data['bairro'] = ""
    for r in realty.find_all('div', {"class":"block-price-container"}):
        try:
            data['transacao'] = r.find('div', {"class": "price-operation"}).text
        except AttributeError:
            data['transacao'] = ""
        try:
            data['preco'] = r.find('div', {"class": "price-items"}).text.strip("R$ ").replace(".", "")
        except AttributeError:
            data['preco'] = ""
        try:
            for c in realty.find_all('div', {"class": "block-expensas block-row"}):
                try:
                    price = c.span.text
                    c.span.extract()
                    expense = c.get_text(strip=True)
                    data[expense] = price.strip("R$ ").replace(".", "")
                except AttributeError:
                    data[expense] = 0
        except AttributeError:
            data[expense] = 0
        try:
            data['descricao'] = realty.find("meta", {"name": "description"})['content']
        except:
            data['descricao'] = ''
    try:
        neighborhood = l.span.text.split(",")
        l.span.extract()
        address = l.get_text(strip=True)
        data['endereco'] = address
        data['bairro'] = neighborhood[1]
        data['cidade'] = neighborhood[2]
    except AttributeError:
        pass
    try:
        days_publication = realty.find('h5',{'class': 'section-date css-float-r'})
        data['dias_publicacao'] = re.findall('(\d+?)\s', days_publication.text)
    except AttributeError:
        pass
        


    realty_data2.append(data)
    sleep(5)

# %%
len(realty_data2)

# %%
df = pd.DataFrame(realty_data2)

# %%
df.to_csv('imovelweb_aluguel_novo_pt1.csv', index=False, encoding='cp1252')
